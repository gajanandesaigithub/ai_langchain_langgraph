# %%
##--------------------------------------
## **      FOR LOOP      **
##--------------------------------------
'''
##Range with single value
print("\n*** FOR LOOP***\nRange with single value e.g. range(5): Default start is 0 and default step is 1")
for i in range(5):
    print (i) ## This will print 0,1,2,3,4

print("\n*** FOR LOOP***\nRange with two values e.g. range(1, 6): Here we mention start from 1, step is default i.e. 1")
for i in range(1, 6):
    print (i)

print("\n*** FOR LOOP***\nRange with three values e.g. range(1, 6, 2): Here we mention start from 1, step as 2")
for i in range(1, 6, 2):
    print (i)

print("\n*** FOR LOOP***\nUsing range for printing in reverse order.")
for i in range(10, 1, -2):
    print(i)

print("\n*** FOR LOOP***\nUsing with strings.")
strName = "Anil"
for i in strName:
    print (i)

print("\n*** FOR LOOP***\n BREAKING FOR LOOP.")

print("\n*** FOR LOOP: BREAK Statement Loop inbetween***\n ")
for i in range (10):
    if (i==5):
        break
    print(i)
'''
'''
print("\n*** FOR LOOP: CONTINUE Statement Loop ***\n ")
for i in range (10):
    if (i%2 == 0):    ##If this condition is satisfied. it will not execute further statements in for loop and will jump to next iteration
        continue
    print(i)
'''
'''
print("\n*** FOR LOOP: PASS Statement Loop ***\n ")
for i in range (10):
    if (i%2 == 0):    ##If this condition is satisfied. it will do nothing and simply go to next statement. It is like null statement.
        pass
    print(i)
'''



##--------------------------------------
## **      WHILE LOOP     **
##--------------------------------------
'''
print("\n*** WHILE LOOP: Loop through to print values***\n ")
count = 0
while count < 10:
    print (count)
    count=count+1
'''

'''
print("\n*** WHILE LOOP: Loop through to print even numbers***\n ")
count=0
while (count%2==0): ##This condition becomes false on second iteration, so it will not go inside inside while loop thereafter
    print(count)
    count=count+1
'''

##--------------------------------------
## **      NESTED LOOPS     **
##--------------------------------------
## Loop inside a loop
