# %% [markdown]
# ### This is Markdown type cell, used to print header! You can use edit option in right to edit text!

# %% [markdown]
# Python Syntax

# %%
## This is single line comment... use double hash.

'''
This is multiline comment 
enclosed within 3 double quotes at start and end
'''
##-------------------------
## Python is case sensitive
##-------------------------


##-------------------------
##Indentation: In Python indentation is used to define blocks of code. e.g. IF BLOCK
##-------------------------
age=32
if age > 30:
    print("Age is greater than 30.")
else:
    print ("Age is less than or equal to 30.")



##-------------------------
## use back slash to continue on next line e.g.
##-------------------------
sum = 3 + 4 + \
    9 + 10

print ("Sum is: ",sum)
print ("Sum is (another way to print): "+ str(sum)) ##Another way to print


##-------------------------
## Multiple statements on single line
##-------------------------
x=5; y=4; z=x+y
print ("Output exampe for multi statements on single line: ", z)

# %% [markdown]
# Python Semantics examples

# %%
## Variable assignment.
##Python inferes type of a variable at runtime, which allows dynamic binding.

age  = 25       ## Here Python automatically defines age as integer and assigns value 32 to it.
print("Type of variable age is : ", type(age))

name = 'Aniket' ## Here Python automatically defines name as string variable and assignes value 'Aniket' to it.
print ("Type of variable name is : ",type(name))

# %% [markdown]
# Variable Naming Conventions

# %%
## Varibale name must start with a letter or underscore
## Variable name must not start with number
## Variables are case sensitive

# %% [markdown]
# User Inputs

# %%
## Use "input" statement to get user input. When you run the below, you will get input box at the top of Jupyter notebook to enter inpu
## Default type of user input is tring

age = input("What is age? ")
print("Your input is:", age, ", Type of your inputis: ", type(age))

## you can change input type
age = int(input("What is age? "))
print("Your input is:", age, ", Type of your inputis: ", type(age))
