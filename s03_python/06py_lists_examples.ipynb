# %%
student_grades = [76, 87, 79, 96]
student_grades.append(95)
print(student_grades)

print("Average of grades:", sum(student_grades)/len(student_grades))
print("Min grade:", min(student_grades), ", Max grade:", max(student_grades))

print("\n\n\n\n\nSearching item in List")
## Check if item is present in List
fruits = ["Mango", "Banana", "Guava", "Grapes"]

##item=input("Which fruit you want search?")
item="Mango"
if item in fruits:
    print("Item ", item, " is present in the fruits list.")
else:
    print("Item ", item, " is not present in the fruits list.")

## Print Fruits list
for item in fruits:
    print(f"-{item}")
