# %%
import os  
## Create new directory
'''
new_dir = "new_folder"
os.mkdir(new_dir)
'''

## Listing all dir and files from a directory
items = os.listdir('.')    ## '.' is current location
print (items)


## Joining paths

## 1. Get relative path
dir_name = "folder"
file_name = "myFile.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)

## 2. get full path
full_path = os.path.join(os.getcwd(), dir_name, file_name)    ## get full path by os.getcwd()
print(full_path)

## Check if file already exists
path = "myFile.txt"
if os.path.exists(path):
    print(f"The path {path} already exists.")
else:
    print(f"The path {path} does not exist.")

## Check if the path is a directory or a file
path = "myFile.txt"
if os.path.isfile(path):
    print(f"The path {path} is a file.")
elif os.path.isdir(path):
    print(f"The path {path} is a directory.")
else:
    print(f"The path {path} is niether a file nor a directory.")

## Getting an absolute path
relative_path = "myFile.txt"
absolute_path = os.path.abspath(path)
print(absolute_path)
# Out:
# ['00py_syntax_n_semantics.ipynb', '01py_basic_datatypes.ipynb', '02py_operations.ipynb', '03py_conditional_operators.ipynb', '04py_loops_in_python.ipynb', '05py_lists_basics.ipynb', '06py_lists_examples.ipynb', '07py_sets.ipynb', '08py_dictionaries.ipynb', '09py_tuples.ipynb', '10py_funtions.ipynb', '11py_lambda_maps_filters.ipynb', '12py_modules_and_packages.ipynb', '13py_creating_your_own_packages.ipynb', '14py_standard_libs.ipynb', '15py_file_ops.ipynb', '16_filepaths.ipynb', 'binExample.bin', 'destination.txt', 'example.csv', 'financials.txt', 'new_folder', 'package', 'read_write_example.txt', 'requirements.txt', 'venv']
# folder\myFile.txt
# c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s03_python\folder\myFile.txt
# The path myFile.txt does not exist.
# The path myFile.txt is niether a file nor a directory.
