# %%
'''
### --------
We can create our own packages in python.
- Let us say we create our packages in a sub-folder named 'package'
- Then in that folder first we need to create a special file names __init__.py
- This file is used to define packages and initialize their namespace
- You can just keep this file empty, but you need to have this file


### --------
'''

## Example
from package.gd_maths import gd_cube
## We can also have subpackage inside a package. We can import it with a dot ".", like from package.subpackage import *


print (gd_cube(3))
# Out:
# 27
