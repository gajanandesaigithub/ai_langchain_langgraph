# %%
### Definition/Syntax

'''
def function_name(parameters)
    """Docstring"""
    #Function body
    return expression

'''

###----------------------------------
### Variable Length Aurguments
###----------------------------------

## Positional and Keyword Arguments

## 1) Positional Arguments.
##      - Here if there are multiple arguments and the number of arguments is not fixed, we user *args as the 
#         input parameter to the function. 
#   For example -

##define function
def read_colors (*args):
    for color in args:
        print (color)

## call function
read_colors("Red","Blue","Green","Yellow","Orange","Purple","White")
# Out:
# Red
# Blue
# Green
# Yellow
# Orange
# Purple
# White
