# %%
### Definition/Syntax

'''
def function_name(parameters)
    """Docstring"""
    #Function body
    return expression

'''

###----------------------------------
### Variable Length Aurguments
###----------------------------------

## A) Positional and Keyword Arguments

## 1) Positional Arguments.
##      - Here if there are multiple arguments and the number of arguments is not fixed, we use *args as the 
#         input parameter to the function. 
#   For example -

##define function
def read_colors (*args):
    for color in args:
        print (color)

## call function
read_colors("Red","Blue","Green","Yellow","Orange","Purple","White")

## 2) Keyword Arguments.
##      - We denote them as **kwargs. Here all the parameters are in key-value pairs
##      For example -
def read_info(**kwargs):
    for key, value in kwargs.items():
        print(f"Key:{key}, Value:{value}")

## call function
read_info (color="Red",drink="Tea",instrument="Guitar")

### we can use both positional arguments and keyword arguments at the same time in a function
def read_colors_and_info(*args, **kwargs):
    ## Accessing Postional arguments 
    for color in args:
        print (color)

    ## Accessing Keyword arguments
    for key, value in kwargs.items():
        print(f"Key:{key}, Value:{value}")

## Return Statements: A function can return multiple parameters
def fn_get_sum_n_product(a,b):
    return a+b, a*b

print(fn_get_sum_n_product(2,3))
