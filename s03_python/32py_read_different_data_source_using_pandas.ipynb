# %%
import pandas as pd


from io import StringIO

Data = '{"emp_name": "Sandeep", "email": "sandeep@gmail.com", "job_profile": [{"title1":"Team Lead", "title2":"Sr. Developer"}]}'
df = pd.read_json(StringIO(Data))
df.to_json()

df.to_json(orient='index')
df.to_json(orient='records')
#df = df.read_csv("you can give URL here..", header=None)
df.to_csv("wine.csv")           # convert the df to csv file

#url = "https://www.fdic.gov/bank-failures/failed-bank-list-failures/failed-bank-list"
url = "https://www.fdic.gov/bank/individual/failed/banklist.html"
df=pd.read_html (url)
df[0]

'''
pandas read_html() will do:
1. Downloads the HTML page
2. Finds all <table> elements
3. Converts each table into a Pandas DataFrame
'''

# match="Country" ==> Pandas scans tables and selects ones whose # content or headers include "Country"
# header=0  ==> Use the first row as column names
url = "https://en.wikipedia.org/wiki/Mobile_country_code"
#df=pd.read_html (url, match="Country", header=0)    

# Reading Excel file
df_excel = pd.read_excel("data.xlsx")
df_excel = pd.read_excel("data.xlsx", sheet_name="Sheet1")


#
'''
to_pickle() is a Pandas method used to save a DataFrame (or Series) to a file using Python’s pickle serialization format.
It stores the DataFrame exactly as it is so you can load it later without recomputing or re-parsing data.

'''
df_excel.to_pickle('df_excel') # This will create pickle file named df_excel
pd.read_pickle("df_excel")
# Out:
#         Name  Age
# 0  Sudhanshu   40
# 1     Mandar   14
# 2      Vicky   38

# %%
#!pip install lxml
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
