# %%
## Standard libraries in Python
import array
import math
import random
import os           ## For file and directory access
import shutil       ## high level operations on files and collections of files
import json         ## data serialization
import csv
from datetime import datetime, timedelta
import time
import re           ## regular expressions

arrNumEven = array.array('i',[2,4,6,8,10])
print(arrNumEven)

print(math.sqrt(5))

print(random.randint(1,10))
print(random.randint(1,10))
print(random.choice(['Red','Blue','Green','Yellow','Orange','Purple','White']))
print(os.getcwd())        ## Get current working directory

##shutil.copyfile('source.txt', 'destination.txt')

## Convert dictionary into json
data = {'name':'Aniket', 'Age':25}
json_str = json.dumps(data)                
print(json_str)
print(type(json_str))

## Convert json back to dictionary
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))


## CSV
## create new file and open it in write mode
with open('example.csv',mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['Aniket',25])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

## datetime
now=datetime.now()
print(now)

yesterday = now-timedelta(days=1)
print(yesterday)

## time
print(time.time())
time.sleep(2)       ## sleep for 2 secs
print(time.time())

## regular expressions library
pattern = '\d+'     ## \d for digits
text = 'The shirt2 is red. 23 23'
match = re.search(pattern,text)
print(match.group())
# Out:
# <>:62: SyntaxWarning: invalid escape sequence '\d'
# <>:62: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\desai\AppData\Local\Temp\ipykernel_1896\448567995.py:62: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d+'     ## \d for digits
# array('i', [2, 4, 6, 8, 10])
# 2.23606797749979
# 6
# 1
# White
# c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s03_python
# {"name": "Aniket", "Age": 25}
# <class 'str'>
# {'name': 'Aniket', 'Age': 25}
# <class 'dict'>
# ['name', 'age']
# ['Aniket', '25']
# 2026-02-09 15:22:42.349561
# 2026-02-08 15:22:42.349561
# 1770630762.349769
# 1770630764.3507826
# 2
