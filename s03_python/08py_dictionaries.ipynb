# %%
###-------------------------------------
###     Definition of Dictionaries in Python
###-------------------------------------
dict_1 = {}        ## Empty Dictionary
dict_2 = dict()    ## Empty Dictionary

print("Type of dict_1",type(dict_1))
print("Type of dict_2", type(dict_2))

dict_buddy = {"name":"Aniket", "age":25, "hobby":"Music"}
print("dict_buddy:",dict_buddy)
print(type(dict_buddy))

###-------------------------------------
###     Accessing elements of Python Dictionaries
###-------------------------------------
print("Buddy name:",dict_buddy['name'])
print("Buddy age:",dict_buddy['age'])
print("Buddy hobby:",dict_buddy['hobby'])

###-------------------------------------
###     Accessing elements of Python Dictionaries using get method
###-------------------------------------
print("Buddy name:",dict_buddy.get('name'))
print("Buddy age:",dict_buddy.get('age'))
print("Buddy hobby:",dict_buddy.get('hobby'))
print("Buddy hobby:",dict_buddy.get('lst_name'))                    ## This prints 'None' because this key does not exist in dictionary
print("Buddy hobby:",dict_buddy.get('lst_name',"Not present"))      ## We can provide default value like "Not Present" for keys that does not exist in dictionary

###     Modifying and Adding elements of Python Dictionaries using get method
dict_buddy["age"]=26                    ## Update existing value
dict_buddy["address"]="Mumbai"          ## Add new key-value
print(dict_buddy)                       ## Delete key-value

del dict_buddy['address']
print(dict_buddy)

###-------------------------------------
###     Methods of Dictionaries
###-------------------------------------
'''
buddy_keys   = dict_buddy.keys()                    ## Get all keys
buddy_values = dict_buddy.values()                  ## Get all values
all_items    = dict_buddy.items()                   ## Get all key-value pairs
print("All keys of buddy dict:", buddy_keys)
print("All values of buddy dict:", buddy_values)
print("All key value pairs of buddy dict:", all_items)

dict_buddy_copy = dict_buddy.copy()                 ## Make shallow copy of dictionary. This makes two separate copies
dict_buddy_copy["name"]="Aniket111"                 ## In shallow copy, changing items of one does not change on others
print("dict_buddy: ", dict_buddy)
print("dict_buddy_copy: ", dict_buddy_copy)
'''

###-------------------------------------
###     Iterating the disctionaries
###-------------------------------------
'''
for key in dict_buddy.keys():
    print(key)

for value in dict_buddy.values():
    print(value)

for (key, value) in dict_buddy.items():
    print(f"Key:{key}, Value:{value}")
'''
###-------------------------------------
###     Nested disctionaries
###-------------------------------------
employees = {
    "employee1":{"name":"Shilpi","dept":"Admin"},
    "employee2":{"name":"Sachin","dept":"IT"}
}
print("employees:",employees)
print("employee1",employees["employee1"])
print("employee1 name:", employees["employee1"]["name"])

###-------------------------------------
###     Iterating Nested disctionaries
###-------------------------------------
for (employee, employee_details) in employees.items():
    print(f"Employee: {employee}, Employee Details: {employee_details}")
    for(key, value) in employee_details.items():
        print(f"Key: {key}, Value: {value}")

###-------------------------------------
###     Dictionary Complrehension
###-------------------------------------
cubes = {num:num**3 for num in range(5)}
print(f"Cubes are, {cubes}")


###-------------------------------------
###     Conditional Dictionary Complrehension
###-------------------------------------
cubes = {num:num**3 for num in range(5) if num%2==0}
print(f"Cubes of even numbers are, {cubes}")


###-------------------------------------
###     Assignment: Use Dictionary to count frequency of elements in list
###-------------------------------------
numbers = [1,2,3, 3,4,5,6,3,4]  ##Declare list
frequency = {}                ##Declare empty dictionary

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print (frequency)

###-------------------------------------
###     Merge two dictionaries into one
###-------------------------------------
dict_1 = {"fruit":"Banana", "drink":"Tea"}
dict_2 = {"instrument":"Guitar", "scale":"Major C"}
merged_dict = {**dict_1, **dict_2}          ## Here double asteric ** is called key word argument. More about it later in functions
print(f"Merged dictionry: {merged_dict}")
# Out:
# Type of dict_1 <class 'dict'>
# Type of dict_2 <class 'dict'>
# dict_buddy: {'name': 'Aniket', 'age': 25, 'hobby': 'Music'}
# <class 'dict'>
# Buddy name: Aniket
# Buddy age: 25
# Buddy hobby: Music
# Buddy name: Aniket
# Buddy age: 25
# Buddy hobby: Music
# Buddy hobby: None
# Buddy hobby: Not present
# {'name': 'Aniket', 'age': 26, 'hobby': 'Music', 'address': 'Mumbai'}
# {'name': 'Aniket', 'age': 26, 'hobby': 'Music'}
# employees: {'employee1': {'name': 'Shilpi', 'dept': 'Admin'}, 'employee2': {'name': 'Sachin', 'dept': 'IT'}}
# employee1 {'name': 'Shilpi', 'dept': 'Admin'}
# employee1 name: Shilpi
# Employee: employee1, Employee Details: {'name': 'Shilpi', 'dept': 'Admin'}
# Key: name, Value: Shilpi
# Key: dept, Value: Admin
# Employee: employee2, Employee Details: {'name': 'Sachin', 'dept': 'IT'}
# Key: name, Value: Sachin
# Key: dept, Value: IT
# Cubes are, {0: 0, 1: 1, 2: 8, 3: 27, 4: 64}
# Cubes of even numbers are, {0: 0, 2: 8, 4: 64}
# {1: 1, 2: 1, 3: 3, 4: 2, 5: 1, 6: 1}
# ...
