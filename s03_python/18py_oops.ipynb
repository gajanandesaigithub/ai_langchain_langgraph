# %%
class Car:
    pass                ## pass is keyword used as placeholder for future code.

audi = Car()
bmw  = Car()
print(type(audi))

##-----------------
## Constructor
##-----------------

class Person:

        def __init__(self, name, age, hobby):
            self.name = name
            self.age = age
            self.hobby = hobby

    ## In Python the first argument of constructor is treated as the 'this' object in java
    # The convension is to keep the name as 'self' but it can be anything. 
    # It represents the instance of class itself.
    # When we do not pass any variable as first argument to constructor, internally python provides it
    # e.g.      when you write:
    #               obj.method(5)
    #           what Python does is:
    #               Class.method(obj, 5)                    

## Create object
person1 = Person("Aniket", 25, "Learning new skills")
print(f"Person name: {person1.name}, person.age: {person1.age}, person hobby: {person1.hobby}")

##-----------------
## Defining instance methods in class
##-----------------
class Furniture:
    def __init__(self, furType, furMaterial, furHeight):
        self.furType = furType
        self.furMaterial = furMaterial
        self.furHeight = furHeight

    def furLife(self):
        if (self.furMaterial.lower())=="wooden":
            print(f"Life of {self.furMaterial} {self.furType} is 50 years.")
        else:
            print(f"Life of {self.furMaterial} {self.furType} is less than 50 years.")


furniture1 = Furniture("Chair", "Wooden", "2.5 feet")
furniture2 = Furniture("Wardrobe", "iron-made", "5.0 feet")
furniture1.furLife()
furniture2.furLife()
# Out:
# <class '__main__.Car'>
# Person name: Aniket, person.age: 25, person hobby: Learning new skills
# Life of Wooden Chair is 50 years.
# Life of iron-made Wardrobe is less than 50 years.
