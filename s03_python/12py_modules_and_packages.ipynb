# %%
import math

print (  math.floor(2.567) )
print ( math.ceil(2.567)  )

# %%
## we can import specific functions from a package and use them directly without math.xx
from math import factorial, isqrt  
## if we want to import all functions of package, we can use *
## from math import *

print ( factorial(5) )
print (isqrt (5) )      ## returns integer square root of given number

# %%
##import sys
##sys.executable

## we can use aliase for package. Refer notes for installing numpy
import numpy as np
np.absolute(-123)
