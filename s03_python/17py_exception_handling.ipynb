# %%
## Common exceptions
##------------------
##  - NameError
##  - ZeroDivisionErro
##  - FileNotfoundError
##  - ValueError
##  - TypeError
##------------------


## try, except block
try:
    a=b
    result = 23/a
except NameError as ex:
    print(f"Variable not defined. The exception is : {ex}")
except ValueError as exVal:
    print("Invalid Number")
except ZeroDivisionError as exZeroDiv:
    print("Please provide non-zero denominator")
except Exception as ex1:                                    ## Main exception
    print(f"Exception occured: {ex1}")
else:                                                       ## Else part eill be executed ONLY IF no exception occurs.
    print(f"The result is {result}")
finally:
    print("Finally block will always be executed, no matter exception occurs or not.")


## Exception handling with file operations
try:
    file=open('inventory.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found.")
finally:
    if 'file' in locals() and not file.closed():
        file.close() 
        print("File closed successfully.")
