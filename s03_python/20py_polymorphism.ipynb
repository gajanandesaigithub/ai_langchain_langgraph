# %%
## Method Overriding



## Polymorphism with abstract base classes (i.e. like interfaces in java)
from abc import ABC, abstractclassmethod

## Define abstract class
class Vehicle(ABC):
    @abstractclassmethod
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car Engine Started"

## Derived class 2
class MotorCycle(Vehicle):
    def start_engine(seld):
        return "MotorCycle Engine Started"

## Calling function
def start_engine(vehicle):
    print(vehicle.start_engine())


## Create objects of Car and motorcycle
car = Car()
motorcycle = MotorCycle()

start_engine(car)
start_engine(motorcycle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 29
#      26 car = Car()
#      27 motorcycle = MotorCycle()
# ---> 29 start_engine(car)
#      30 start_engine(motorcycle)
#
# NameError: name 'start_engine' is not defined
