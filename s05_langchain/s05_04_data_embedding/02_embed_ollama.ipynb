# %%
# !pip install -U langchain-ollama
# Out:
# ...
#
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# ...

# %%
#from langchain_community.embeddings import OllamaEmbeddings --> depricated
from langchain_ollama import OllamaEmbeddings

embeddings=(
    OllamaEmbeddings(model="gemma:2b")   # by default it take llama2 model, if you want ot use that, make sure you first install it
)
embeddings

r1 = embeddings.embed_documents(
    [
        "A is the first letter of alphabets.",
        "B is the second letter of alphabets."
    ]
)
r1
r1[0]
len(r1[0])

embeddings.embed_query("What is second letter of alphabet")
# Out:
# 2048
