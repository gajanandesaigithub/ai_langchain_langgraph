# %% [markdown]
# #### Embedding Techniques
#     Converting text into vectors

# %%
#!pip install langchain-openai

import sys
print(sys.executable)

# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings

load_dotenv()     # Loading env variables



os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
embeddings

text = "Siddhartha Gautama, most commonly referred to as the Buddha was a wandering ascetic."
query_result = embeddings.embed_query(text) # This will convert to vectors
query_result 

len(query_result)  # Check dimension of result = 3072 default for this model

# We can also set our own dimension
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)
query_result = embeddings_1024.embed_query(text)
len(query_result)
# Out:
# 1024

# %%
# We can convert text to vector for an entire document
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

## Text Loader
loader = TextLoader('Gautam_buddha.txt')
docs = loader.load()
docs

# Split it into data chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text = text_splitter.split_documents(docs)
text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#      10 # Split it into data chunks
#      11 text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
# ---> 12 text = text_splitter.create_documents(docs)
#      13 text
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_text_splitters\base.py:120, in TextSplitter.create_documents(self, texts, metadatas)
#     118 index = 0
#     119 previous_chunk_len = 0
# --> 120 for chunk in self.split_text(text):
#     121     metadata = copy.deepcopy(metadatas_[i])
#     122     if self._add_start_index:
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_text_splitters\character.py:158, in RecursiveCharacterTextSplitter.split_text(self, text)
#     149 def split_text(self, text: str) -> list[str]:
#     150     """Split the input text into smaller chunks based on predefined separators.
#     151
#     152     Args:
#    (...)    156         A list of text chunks obtained after splitting.
#     157     """
# --> 158     return self._split_text(text, self._separators)
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_text_splitters\character.py:118, in RecursiveCharacterTextSplitter._split_text(self, text, separators)
#     116     separator = s_
#     117     break
# --> 118 if re.search(separator_, text):
#     119     separator = s_
#     120     new_separators = separators[i + 1 :]
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'Document'
