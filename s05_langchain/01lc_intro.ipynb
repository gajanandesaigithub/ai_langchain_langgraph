# %% [markdown]
# #### Langchain & OpenAI
# - Get Setup with LangChain, LangSmith and LangServe
# - Use basic and common components of LangChain - prompt templates, models & output parsers
# - Build a simple application with LangChain
# - Trace application with LangSmith (debugging, monitoring..)
# - Serve application with LangServe
#
# Sign up into lanchain.com: https://smith.langchain.com/
# Sign up in OpenAI
