# %% [markdown]
# #### How to recursively text by characters

# %%
#### How to recursively text by characters
#from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
#import time
from langchain_community.document_loaders import TextLoader
'''
time.sleep(3)
docs = ArxivLoader(query="attention is all you need", load_max_docs=2).load()
len(docs)
print (docs[0])
'''

# With PDF loader
loader = PyPDFLoader('fire-emergency-plan.pdf')
pdf_doc = loader.load()
pdf_doc

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_document = text_splitter.split_documents(pdf_doc)
'''
#final_document
print(final_document[5].page_content)
print("--------------------------------------")
print(final_document[6])
print("--------------------------------------")
print(final_document[7])
print("--------------------------------------")
'''

# With Text loader
loader = TextLoader('Gautam_buddha.txt')
loader
text_doc = loader.load()
text_doc

speech = ""
with open("Gautam_buddha.txt") as f:
    speech = f.read()
speech

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text = text_splitter.create_documents([speech])
print(text)
# Out:
# [Document(metadata={}, page_content='Siddhartha Gautama, most commonly referred to as the Buddha was a wandering ascetic and religious'), Document(metadata={}, page_content='and religious teacher who lived in the eastern Indo-Gangetic Plains during the 6th or 5th century'), Document(metadata={}, page_content='6th or 5th century BCE and founded Buddhism.'), Document(metadata={}, page_content='According to Buddhist legends, he was born in Lumbini, in what is now Nepal,to royal parents of the'), Document(metadata={}, page_content='parents of the Shakya clan, but renounced his home life to live as a wandering ascetic. After'), Document(metadata={}, page_content='ascetic. After leading a life of mendicancy, asceticism, and meditation, he attained nirvana at'), Document(metadata={}, page_content='attained nirvana at Bodh Gaya in what is now Bihar, India.'), Document(metadata={}, page_content='The Buddha then wandered through the lower Indo-Gangetic Plain, teaching and building a monastic'), Document(metadata={}, page_content='building a monastic order (sangha).'), Document(metadata={}, page_content='Buddhist tradition holds he died in Kushinagar (in modern day Uttar Pradesh, India) and reached'), Document(metadata={}, page_content='India) and reached parinirvana ("final release from conditioned existence").'), Document(metadata={}, page_content='Ref: https://en.wikipedia.org/wiki/The_Buddha')]
