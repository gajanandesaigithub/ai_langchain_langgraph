# %% [markdown]
# #### How to recursively text by characters

# %%
#### How to recursively text by characters
#from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
#import time
from langchain_community.document_loaders import TextLoader
'''
time.sleep(3)
docs = ArxivLoader(query="attention is all you need", load_max_docs=2).load()
len(docs)
print (docs[0])
'''

# With PDF loader
loader = PyPDFLoader('fire-emergency-plan.pdf')
pdf_doc = loader.load()
pdf_doc

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_document = text_splitter.split_documents(pdf_doc)
'''
#final_document
print(final_document[5].page_content)
print("--------------------------------------")
print(final_document[6])
print("--------------------------------------")
print(final_document[7])
print("--------------------------------------")

# Note: PDFs often have weird line breaks, hidden formatting, So overlap may look inconsistent

'''

# With Text loader
loader = TextLoader('Gautam_buddha.txt')
loader
text_doc = loader.load()
text_doc

speech = ""
with open("Gautam_buddha.txt") as f:
    speech = f.read()
speech

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
text = text_splitter.create_documents([speech])
print(text[0])
print(text[1])
print(text[2])
# Out:
# page_content='Siddhartha Gautama, most commonly referred to as the Buddha was a wandering ascetic and religious'
# page_content='and religious teacher who lived in the eastern Indo-Gangetic Plains during the 6th or 5th century'
# page_content='6th or 5th century BCE and founded Buddhism.'
