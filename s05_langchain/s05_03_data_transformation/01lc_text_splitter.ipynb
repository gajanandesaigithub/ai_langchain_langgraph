# %% [markdown]
# #### How to recursively text by characters

# %%
#### How to recursively text by characters
#from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
#import time

'''
time.sleep(3)
docs = ArxivLoader(query="attention is all you need", load_max_docs=2).load()
len(docs)
print (docs[0])
'''

loader = PyPDFLoader('sample-1.pdf')
pdf_doc = loader.load()
pdf_doc

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_document = text_splitter.split_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:695, in Client._parse_feed(self, url, first_page, _try_index)
#     694 try:
# --> 695     return self.__try_parse_feed(url, first_page=first_page, try_index=_try_index)
#     696 except (
#     697     HTTPError,
#     698     UnexpectedEmptyPageError,
#     699     requests.exceptions.ConnectionError,
#     700 ) as err:
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:732, in Client.__try_parse_feed(self, url, first_page, try_index)
#     731 if resp.status_code != requests.codes.OK:
# --> 732     raise HTTPError(url, try_index, resp.status_code)
#     734 feed = feedparser.parse(resp.content)
#
# HTTPError: Page request resulted in HTTP 429 (https://export.arxiv.org/api/query?search_query=attention+is+all+you+need&id_list=&sortBy=relevance&sortOrder=descending&start=0&max_results=100)
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:695, in Client._parse_feed(self, url, first_page, _try_index)
#     694 try:
# --> 695     return self.__try_parse_feed(url, first_page=first_page, try_index=_try_index)
#     696 except (
#     697     HTTPError,
#     698     UnexpectedEmptyPageError,
#     699     requests.exceptions.ConnectionError,
#     700 ) as err:
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:732, in Client.__try_parse_feed(self, url, first_page, try_index)
#     731 if resp.status_code != requests.codes.OK:
# --> 732     raise HTTPError(url, try_index, resp.status_code)
#     734 feed = feedparser.parse(resp.content)
#
# HTTPError: Page request resulted in HTTP 429 (https://export.arxiv.org/api/query?search_query=attention+is+all+you+need&id_list=&sortBy=relevance&sortOrder=descending&start=0&max_results=100)
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:695, in Client._parse_feed(self, url, first_page, _try_index)
#     694 try:
# --> 695     return self.__try_parse_feed(url, first_page=first_page, try_index=_try_index)
#     696 except (
#     697     HTTPError,
#     698     UnexpectedEmptyPageError,
#     699     requests.exceptions.ConnectionError,
#     700 ) as err:
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:732, in Client.__try_parse_feed(self, url, first_page, try_index)
#     731 if resp.status_code != requests.codes.OK:
# --> 732     raise HTTPError(url, try_index, resp.status_code)
#     734 feed = feedparser.parse(resp.content)
#
# HTTPError: Page request resulted in HTTP 429 (https://export.arxiv.org/api/query?search_query=attention+is+all+you+need&id_list=&sortBy=relevance&sortOrder=descending&start=0&max_results=100)
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 import time
#       6 time.sleep(3)
# ----> 7 docs = ArxivLoader(query="attention is all you need", load_max_docs=2).load()
#       8 len(docs)
#       9 print (docs[0])
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_community\document_loaders\arxiv.py:149, in ArxivLoader.lazy_load(self)
#     147 def lazy_load(self) -> Iterator[Document]:
#     148     """Lazy load Arvix documents"""
# --> 149     yield from self.client.lazy_load(self.query)
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\langchain_community\utilities\arxiv.py:218, in ArxivAPIWrapper.lazy_load(self, query)
#     215     logger.debug("Error on arxiv: %s", ex)
#     216     return
# --> 218 for result in results:
#     219     try:
#     220         doc_file_name: str = result.download_pdf()
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:648, in Client._results(self, search, offset)
#     646 def _results(self, search: Search, offset: int = 0) -> Generator[Result, None, None]:
#     647     page_url = self._format_url(search, offset, self.page_size)
# --> 648     feed = self._parse_feed(page_url, first_page=True)
#     649     if not feed.entries:
#     650         logger.info("Got empty first page; stopping generation")
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:703, in Client._parse_feed(self, url, first_page, _try_index)
#     701 if _try_index < self.num_retries:
#     702     logger.debug("Got error (try %d): %s", _try_index, err)
# --> 703     return self._parse_feed(url, first_page=first_page, _try_index=_try_index + 1)
#     704 logger.debug("Giving up (try %d): %s", _try_index, err)
#     705 raise err
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:703, in Client._parse_feed(self, url, first_page, _try_index)
#     701 if _try_index < self.num_retries:
#     702     logger.debug("Got error (try %d): %s", _try_index, err)
# --> 703     return self._parse_feed(url, first_page=first_page, _try_index=_try_index + 1)
#     704 logger.debug("Giving up (try %d): %s", _try_index, err)
#     705 raise err
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:703, in Client._parse_feed(self, url, first_page, _try_index)
#     701 if _try_index < self.num_retries:
#     702     logger.debug("Got error (try %d): %s", _try_index, err)
# --> 703     return self._parse_feed(url, first_page=first_page, _try_index=_try_index + 1)
#     704 logger.debug("Giving up (try %d): %s", _try_index, err)
#     705 raise err
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:705, in Client._parse_feed(self, url, first_page, _try_index)
#     703     return self._parse_feed(url, first_page=first_page, _try_index=_try_index + 1)
#     704 logger.debug("Giving up (try %d): %s", _try_index, err)
# --> 705 raise err
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:695, in Client._parse_feed(self, url, first_page, _try_index)
#     688 """
#     689 Fetches the specified URL and parses it with feedparser.
#     690
#     691 If a request fails or is unexpectedly empty, retries the request up to
#     692 `self.num_retries` times.
#     693 """
#     694 try:
# --> 695     return self.__try_parse_feed(url, first_page=first_page, try_index=_try_index)
#     696 except (
#     697     HTTPError,
#     698     UnexpectedEmptyPageError,
#     699     requests.exceptions.ConnectionError,
#     700 ) as err:
#     701     if _try_index < self.num_retries:
#
# File c:\Gajanan\Work\GitHubRepos\ai_langchain_langgraph\s05_langchain\venv\Lib\site-packages\arxiv\__init__.py:732, in Client.__try_parse_feed(self, url, first_page, try_index)
#     730 self._last_request_dt = datetime.now()
#     731 if resp.status_code != requests.codes.OK:
# --> 732     raise HTTPError(url, try_index, resp.status_code)
#     734 feed = feedparser.parse(resp.content)
#     735 if len(feed.entries) == 0 and not first_page:
#
# HTTPError: Page request resulted in HTTP 429 (https://export.arxiv.org/api/query?search_query=attention+is+all+you+need&id_list=&sortBy=relevance&sortOrder=descending&start=0&max_results=100)
