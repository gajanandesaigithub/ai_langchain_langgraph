# %% [markdown]
# #### How to recursively text by characters

# %%
#### How to recursively text by characters
#from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
#import time

'''
time.sleep(3)
docs = ArxivLoader(query="attention is all you need", load_max_docs=2).load()
len(docs)
print (docs[0])
'''

loader = PyPDFLoader('fire-emergency-plan.pdf')
pdf_doc = loader.load()
pdf_doc

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_document = text_splitter.split_documents(pdf_doc)
#final_document
print(final_document[0])
print(final_document[1])
print(final_document[2])
print(final_document[3])
# Out:
# page_content='Fire Safety Management
# and
# Fire Emergency Plan
# for
#
# Company Name:
#
#
#
# Address:' metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2020-09-23T15:21:47+01:00', 'author': 'John Stephenson', 'moddate': '2020-09-23T15:32:39+01:00', 'title': 'Fire Safety Management and Fire  Emergency Plan', 'source': 'fire-emergency-plan.pdf', 'total_pages': 27, 'page': 0, 'page_label': '1'}
# page_content='This page is left intentionally blank to allow for printing on both sides.' metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2020-09-23T15:21:47+01:00', 'author': 'John Stephenson', 'moddate': '2020-09-23T15:32:39+01:00', 'title': 'Fire Safety Management and Fire  Emergency Plan', 'source': 'fire-emergency-plan.pdf', 'total_pages': 27, 'page': 1, 'page_label': '2'}
# page_content='Fire Safety Management
#
#
# Statement of Intent
#
# [company / organisation / business name] believes that ensuring the health and safety of staff,
# visitors, service users and all relevant persons is essential to our success.
#
# We are committed to:
#
# 1. Preventing accidents and work-related ill health.
# 2. Compliance with statutory requirements as a minimum.
# 3. Assessing and controlling the risks that arise from our work activities.' metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2020-09-23T15:21:47+01:00', 'author': 'John Stephenson', 'moddate': '2020-09-23T15:32:39+01:00', 'title': 'Fire Safety Management and Fire  Emergency Plan', 'source': 'fire-emergency-plan.pdf', 'total_pages': 27, 'page': 2, 'page_label': '3'}
